# %%
student_name = "Amara"

age = 19

subject = "Math"

score = 72

passed = True

# %%
type(student_name)
# Out:
# str

# %%
type(age)
# Out:
# int

# %%
type(subject)
# Out:
# str

# %%
type(score)
# Out:
# int

# %%
type(passed)
# Out:
# bool

# %%
final_mark = (72/100)*105
print(final_mark)
# Out:
# 75.6

# %%
type(final_mark)
# Out:
# float

# %%
student_name = ["Amara", "Ben", "Chloe", "David", "Eva", "Farai", "Grace", "Hassan"]

# %%
student_name[0],student_name[-1]
# Out:
# ('Amara', 'Hassan')

# %%
student_name[2:5]
# Out:
# ['Chloe', 'David', 'Eva']

# %%
len(student_name)
# Out:
# 8

# %%
 scores = [72, 55, 88, 45, 91, 63, 50, 77]

# %%
scores[4], scores[0]
# Out:
# (91, 72)

# %%
scores[0]+scores[4]
# Out:
# 163

# %%
hassan = {
    "student_name": "hassan",
    "age": 21,
    "subject": "Science",
    "score": 77,
    "passed": "true"
}

# %%
hassan["subject"]
# Out:
# 'Science'

# %%
hassan["score"]+10
# Out:
# 87

# %%
(hassan["passed"])
# Out:
# 'true'

# %%
students = [
    {"student_name": "Amara", "score": 72},
    {"student_name": "Ben", "score": 55},
    {"student_name": "Chloe", "score": 88},
    {"student_name": "david", "score": 45},
]

# %%
students[1]["score"]
# Out:
# 55

# %%
print(score > 60)
# Out:
# True

# %%
students[0]["score"] > 60
# Out:
# True

# %%
	age == 20
# Out:
# False

# %%
	score >= 72
# Out:
# True

# %%
	subject != "Science"
# Out:
# True

# %%
	score > 60 and passed == True
# Out:
# True

# %%
	age < 18 or score > 70
# Out:
# True

# %%
	not passed
# Out:
# False

# %%
	score > 80 and subject == "Math"
# Out:
# False

# %%
if score >= 75:
   print("distinction") 
elif score >=50:
    print("pass") 
else:
    print("fail")
    score = 72
# Out:
# pass

# %%
score = 45

if score >= 75:
   print("distinction") 
elif score >=50:
    print("passed") 
else:
    print("fail")
# Out:
# fail

# %%
score = 90
if score >= 75:
   print("distinction") 
elif score >=50:
    print("passed") 
else:
    print("fail")
# Out:
# distinction

# %%
students = [
    {"student_name": "Amara", "score": 72, "subject": "math"},
    {"student_name": "Ben", "score": 55, "subject": "science"}
]

# %%
# cheching if it will run
print(students)
# Out:
# [{'student_name': 'Amara', 'score': 72, 'subject': 'math'}, {'student_name': 'Ben', 'score': 55, 'subject': 'science'}]

# %%
for student in students:
    score = student["score"]
    subject = student["subject"]
    if score > 60 and subject == "math":
       print(student["student_name"],":", "math high achiever")
    else:
     print(student["student_name"], ":", "does not meet criteria")
# Out:
# Amara : math high achiever
# Ben : does not meet criteria
